# %% [markdown]
# # Hello Jupyter Notebook
#
# This is a simple example notebook to demonstrate the JupyterLab setup.

# %%
print("Hello, Jupyter!")

# %% [markdown]
# ## Example with Python
#
# You can add any Python packages you need to the `pyproject.toml` file.

# %%
# Example: Working with lists and basic Python
numbers = [1, 2, 3, 4, 5]
squared = [n**2 for n in numbers]

print(f"Numbers: {numbers}")
print(f"Squared: {squared}")
print(f"Sum: {sum(squared)}")
